# %%
import matplotlib.pyplot as plt

# %%
X = [1, 2, 3]
Y = [1, 3, 4]
plt.plot(X, Y) # X와 Y를 따로따로 관리
plt.show()

# %%
X = [1, 2, 3]
Y = [1, 3, 4]
plt.plot(X, Y, 'o--') # 점선, dot추가
plt.show()

# %%
# Y에 함수, 회귀식 그래프 형태 만들기
X = range(-20, 21)
Y = [x**2 + 1 for x in X]
plt.plot(X, Y, 'o--')
plt.show()

# %%
X = range(0, 5)
Y = [2*x+1 for x in X]
plt.plot(X, Y)
DataX = [1, 3, 4]
DataY = [2.9, 7.1, 9.3]
plt.plot(DataX, DataY, 'o')     #원본 리얼 데이터를 쓸때 'o'를 사용
plt.show()

# %%
import math as m # y = sin(2*pi*t)

X = range(0, 20)
Y = [m.sin(x) for x in X]
plt.plot(X, Y, 'o--')

# 왜 그래프까 꺾이지 -> 곡선이 되기에는 점이 부족한 느낌.

# %%
# linear space -> range 함수 아쉬움 보완
import numpy as np
X = np.linspace(0, 1, 4)
print(X)
# Out:
# [0.         0.33333333 0.66666667 1.        ]

# %%
import math as m # y = sin(2*pi*t)

X = range(0, 40, 1)
Y = [m.sin(x/5) for x in X]   # 점 개수 조절을 위해 한 나누기
plt.plot(X, Y, 'o--')

# %%
X = np.linspace(0, 2*np.pi, 100)   # 개수가 줄면 꺾임이 생기고 많으면 곡선이 됨.
Y = np.sin(X)
plt.plot(X, Y)
plt.show()

# %%
data = np.random.rand(100, 2)
data.shape
# Out:
# (100, 2)

# %%
plt.scatter(data[:, 0], data[:, 1])
plt.show()
#데이터 개수가 적을때는 이런 모형 쓰는 것 아님

# %%
data1 = np.random.rand(100, 2)
data2 = np.random.rand(100, 2)
data3 = np.random.rand(100, 2)
data1 += np.array((-2, -2))
data2 += np.array((2, 0))
data3 += np.array((2, -0.7))
plt.scatter(data1[:, 0], data1[:, 1])
plt.scatter(data2[:, 0], data2[:, 1])
plt.scatter(data3[:, 0], data3[:, 1])
plt.show()

# %%
data = [5, 25, 100, 50]
index = [1, 2, 3, 4]
plt.bar(index, data)
plt.show()

# %%
data = [5, 25, 100, 50]
index = [10, 20, 30, 40]
plt.bar(index, data)
plt.show()

# %%
# 문자 인덱스
data = [5, 25, 100, 50]
index = ['a', 'b', 'c', 'd'] # 10, 20, 30, 40
plt.bar(index, data)
plt.show()

# %%
# 폭 조절
data = [5, 25, 100, 50]
index = [10, 20, 30, 40]
plt.bar(index, data, width= 8)
plt.show()

# %%
# barh -> 가로 방향. width= x 사용 불가
data = [5, 25, 100, 50]
index = [1, 2, 3, 4]
plt.barh(index, data)
plt.show()

# %%
data1 = [5, 25, 100, 50]; index1 = [1, 6, 11, 16]  # index조절해서 위치 조정
data2 = [2, 20, 10, 40]; index2 = [2, 7, 12, 17]
data3 = [3, 28, 60, 30]; index3 = [3, 8, 13, 18]
plt.bar(index1, data1)
plt.bar(index2, data2)
plt.bar(index3, data3)
plt.show()

# %%
# 파이그래프: 백분율로 알아서 표현됨
data = [75, 25, 50, 20]
plt.pie(data)
plt.show()

# %%
# 히스토그램
data = np.random.randn(1000)
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data, bins= 20)   # bins는 막대 개수
plt.show()
#튀어 나온게 많으면 머신러닝할때도 문제가 됨

# %%
data = np.random.randn(1000)
plt.boxplot(data)
plt.show()

# %%
data = np.random.randn(1000, 5)
data += np.array([-2, 2, 0, 1, 5]) #중앙점
plt.boxplot(data)
plt.show()

# %%
dataA = np.random.standard_normal((100, 2))
dataB = np.random.standard_normal((100, 2))
dataC = np.random.standard_normal((100, 2))
dataA += np.array((-3, -3))
dataB += np.array((4, 4))
dataC += np.array((-1, 4))
plt.scatter(dataA[:, 0], dataA[:, 1], color= 'b')   # 색상 앞 alphabet
plt.scatter(dataB[:, 0], dataB[:, 1], color= '#B2CCFF')  # color palette number from naver
plt.scatter(dataC[:, 0], dataC[:, 1], color= '0.5')  # 색이 옅어짐. 1 = white, 0 = black
plt.show()

# %%
dataA = np.random.standard_normal((100, 2))
dataB = np.random.standard_normal((100, 2))
dataC = np.random.standard_normal((100, 2))
dataA += np.array((-3, -3))
dataB += np.array((4, 4))
dataC += np.array((-1, 4))
plt.scatter(dataA[:, 0], dataA[:, 1], edgecolor= '0', color= 'b')   # edgecolor -> 테두리 색
plt.scatter(dataB[:, 0], dataB[:, 1], edgecolor= '0', color= '#B2CCFF')
plt.scatter(dataC[:, 0], dataC[:, 1], edgecolor= '0', color= '0.5')
plt.show()

# %%
import matplotlib.cm as cm  # color map
N = 256
angle = np.linspace(0, 8*2*np.pi, N)
radius = np.linspace(5, 1, N)
X = radius*np.cos(angle)
Y = radius*np.sin(angle)
plt.scatter(X, Y, c= angle)
plt.show()

# %%
import matplotlib.cm as cm  # color map
N = 256
angle = np.linspace(0, 8*2*np.pi, N)
radius = np.linspace(5, 1, N)
X = radius*np.cos(angle)
Y = radius*np.sin(angle)
plt.scatter(X, Y, c= angle, cmap= cm.Spectral) # cm.Greys, cm.hsv
plt.show()

# %%
X = np.linspace(-10, 10, 100)
Y1 = [2*x**2+1 for x in X]
Y2 = [3*x**2+5 for x in X]
Y3 = [0.5*x**2+3 for x in X]
plt.plot(X, Y1)
plt.plot(X, Y2)
plt.plot(X, Y3)
plt.show()

# %%
X = np.linspace(-10, 10, 100)
Y1 = [2*x**2+1 for x in X]
Y2 = [3*x**2+5 for x in X]
Y3 = [0.5*x**2+3 for x in X]
plt.plot(X, Y1, linestyle= 'solid')
plt.plot(X, Y2, linestyle= 'dashed')
plt.plot(X, Y3, linestyle= 'dashdot')
plt.show()

# %%
N = 4
A = np.random.random(N)
B = np.random.random(N)
X = np.arange(N)
plt.bar(X, A, color= '#5872A5')
plt.bar(X, A+B, bottom= A, color= '#B2CCFF')

plt.show()

# %%
N = 4
A = np.array([1, 2, 3, 2])
B = np.array([2, 3, 2, 1])
C = np.array([1, 4, 2, 3])
X = np.arange(N)
plt.bar(X, A, color= '#344E81')
plt.bar(X, B, bottom= A, color= '#5872A5')
plt.bar(X, C, bottom= A+B, color= '#B2CCFF')

plt.show()

# %%
N = 4
A = np.array([1, 2, 3, 2])
B = np.array([2, 3, 2, 1])
C = np.array([1, 4, 2, 3])
X = np.arange(N)
plt.bar(X, A, color= '#344E81', hatch= '/')
plt.bar(X, B, bottom= A, color= '#5872A5', hatch= 'x')  # hatch option -> back slash는 안됨
plt.bar(X, C, bottom= A+B, color= '#B2CCFF')

plt.show()

# %%
women_pop = np.array([5, 30, 45, 22])
men_pop = np.array([15, 25, 50, 20])
X = np.arange(4)
plt.barh(X, women_pop, color= 'r')
plt.barh(X, -men_pop, color= 'b') # men_pop에 - 붙임
plt.show()

# %%
A = np.random.standard_normal((100, 2))
B = np.random.standard_normal((100, 2))
A += np.array((-1, -2))
B += np.array((0.5, 1))
plt.scatter(A[:, 0], A[:, 1], color= 'k', marker= 'o')
plt.scatter(B[:, 0], B[:, 1], color= 'k', marker= 'x') 
# marker= '^', 'v', '>', '<' -> triangles / 's' -> square / 'p' -> pentagon / 'P' -> plus / '*' / 'X' / 'D' -> diamond / ' ' / '.'

plt.show()

# %%
X = np.linspace(-6, 6, 1024)
Y1 = np.sinc(X)
Y2 = np.sinc(X)+1
plt.plot(X, Y1, marker= 'o', color= '0.7')
plt.plot(X, Y2, marker= 'o', color= '0.4', markevery= 32)  # 마커 간격
plt.show()

# %%
A = np.random.standard_normal((100, 2))
B = np.random.standard_normal((100, 2))
A += np.array((-1, -2))
B += np.array((0.5, 1))
plt.scatter(A[:, 0], A[:, 1], s= 10) # size 설정
plt.scatter(B[:, 0], B[:, 1], s= 100)
plt.show()

# %%
M = np.random.standard_normal((500, 2))
R = np.sum(M**2, axis= 1)
plt.scatter(M[:, 0], M[:, 1], c= '0.7', marker= 's', s= 32*R, edgecolor= 'k')
plt.show()

# %%
M = np.random.standard_normal((500, 2))
R = np.sum(M**2, axis= 1)
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.scatter(M[:, 0], M[:, 1], c= '0.7', marker= 's', s= 32*R, edgecolor= 'k')
plt.show()

# %%
X = np.linspace(-6, 6, 1024)
X_small = np.linspace(-3, 3, 1024)
Y_small = np.sinc(X_small)
plt.plot(X, np.sinc(X), color= '0.7')
sub_axes = plt.axes([0.6, 0.6, 0.25, 0.25])
sub_axes.plot(X_small, Y_small, color= '0.0')
plt.show()

# %%
T = np.linspace(0, 2*np.pi, 1024) # 한바퀴 돌리기 위한 범위 0 : 2pi
plt.axes(polar= True) # polar 극좌표계
plt.plot(T, 1+0.25*np.sin(16*T))
plt.show()

# %%
import matplotlib.patches as patches
plt.axes(polar= True)

radius = [1, 0.5, 0.7, 0.3, 0.1, 0.2, 0.6, 0.8, 0.5]
theta = np.linspace(0, 2*np.pi, len(radius), endpoint= False)
points = np.vstack((theta, radius)).T # 행렬 차원 맞춘다. 일단 pass
plt.gca().add_patch(patches.Polygon(points, color= '0.5'))
plt.show()

# %%
# 228pg
import pandas as pd
data = [1, 2, 3, 4]
df1 = pd.DataFrame(data)
df1
print('mean:', df1.mean())
print('median:', df1.median()) # 균일한 데이터일 때 mean = median
# Out:
# mean: 0    2.5
# dtype: float64
# median: 0    2.5
# dtype: float64

# %%
import pandas as pd
data = [1, 2, 3, 4, 50]
df1 = pd.DataFrame(data)
df1
print('mean:', df1.mean())
print('median:', df1.median())
# 이 경우에는 dataset의 대표성을 지니는 값 = median -> not all the time mean is the best
# Out:
# mean: 0    12.0
# dtype: float64
# median: 0    3.0
# dtype: float64

# %%
#공분산
x = [8, 3, 6 ,6, 9, 4, 3, 9, 3, 4]
y= [6, 2, 4, 6, 10, 5, 1, 8, 4, 5]
plt.plot(x,y,"o")
plt.show()

# %%
np.cov(x,y)
# Out:
# array([[6.05555556, 5.61111111],
#        [5.61111111, 6.98888889]])

# %%
covar = np.cov(x,y)[0,1]
covar
# Out:
# 5.61111111111111

# %%
plt.figure(figsize=(5,5))
x = [1,10,10,1,2,9,9,2]
y = [1,1,10,10,2,2,9,9]
plt.plot(x,y,"o")
plt.show()
covar = np.cov(x,y)[0,1]
covar
# Out:
# 0.0

# %%
plt.figure(figsize=(5,5))
x = np.random.random(20)
y = np.random.random(20)
plt.plot(x,y,"o")
plt.show()
covar = np.cov(x,y)[0,1]
covar
# Out:
# 0.00564234484094447

# %% [markdown]
# # 설치
# #pip install pandas-datareader

# %%
import pandas_datareader.data as web

# %%
all_data={ticker: web.get_data_yahoo(ticker)
         for ticker in ["AAPL","IBM","MSFT","GOOG"]}
price = pd.DataFrame({ticker : data['Adj Close']
                                    for ticker, data in all_data.items()})
volume = pd.DataFrame({ticker : data['Volume']
                                     for ticker, data in all_data.items()})

# %%
price.head()
# Out:
#                  AAPL         IBM       MSFT        GOOG
# Date
# 2016-05-31  23.321924  123.099327  48.826679  735.719971
# 2016-06-01  22.994963  122.114479  48.688492  734.150024
# 2016-06-02  22.822144  122.907143  48.347626  730.400024
# 2016-06-03  22.868847  122.418724  47.711952  722.340027
# 2016-06-06  23.034662  122.290611  48.025192  716.549988
